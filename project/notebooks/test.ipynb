# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.field import Field
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.field import Field
#
# ModuleNotFoundError: No module named 'src'

# %%
test_field = Field(field_size=5, initial_agents=3)
print(f"初期個体数: {len(test_field.agents)}")

for i in range(10):
    test_field.step()
    print(f"Step {i+1}: 生存個体数={len(test_field.agents)}, 利他行動数={test_field.altruism_count}")
    test_field.altruism_count = 0
